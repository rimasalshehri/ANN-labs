# %%
import numpy as np 
import matplotlib.pyplot as plt
import random

# %% [markdown]
# # Q1

# %%
def sigmoid(z):
    return 1.0/(1+np.exp(-z))

# %%
def logsiglayer(w1,p,b1):
    n=np.dot(w1,p)+b1
    a1=sigmoid(n)
    return a1

# %% [markdown]
# # Q2

# %%
def purelin(n):
    return n

# %%
def linearlayer(w2,a1,b2):
    a2=np.dot(w2,a1)+b2 
    return a2

# %% [markdown]
# # Q3

# %%
w1=np.array([[10],
             [10]])
b1=np.array([[-10],
             [10]])
w2=np.array([[1,1]])
b2=np.array([[0]])

# %%
p=np.array([np.linspace(-2,2)])
a1=logsiglayer(w1,p,b1)
a2=linearlayer(w2,a1,b2)

# %%
plt.figure(figsize=(10,10))
plt.scatter(p,a2)
plt.show()

# %% [markdown]
# # Q4

# %%
b11=np.array([[10],
             [10]])

b12=np.array([[9],
             [10]])

b13=np.array([[8],
             [10]])

b14=np.array([[7],
             [10]])

b15=np.array([[6],
             [10]])

b16=np.array([[5],
             [10]])

b17=np.array([[4],
             [10]])

b18=np.array([[3],
             [10]])

b19=np.array([[2],
             [10]])

b01=np.array([[1],
             [10]])


a11=logsiglayer(w1,p,b11)
a21=linearlayer(w2,a11,b2)

a12=logsiglayer(w1,p,b12)
a22=linearlayer(w2,a12,b2)

a13=logsiglayer(w1,p,b13)
a23=linearlayer(w2,a13,b2)


a14=logsiglayer(w1,p,b14)
a24=linearlayer(w2,a14,b2)

a15=logsiglayer(w1,p,b15)
a25=linearlayer(w2,a15,b2)


a16=logsiglayer(w1,p,b16)
a26=linearlayer(w2,a16,b2)


a17=logsiglayer(w1,p,b17)
a27=linearlayer(w2,a17,b2)


a18=logsiglayer(w1,p,b18)
a28=linearlayer(w2,a18,b2)


a19=logsiglayer(w1,p,b19)
a29=linearlayer(w2,a19,b2)


a10=logsiglayer(w1,p,b01)
a20=linearlayer(w2,a10,b2)





plt.figure(figsize=(10,10))
plt.scatter(p,a21)
plt.scatter(p,a22)
plt.scatter(p,a23)
plt.scatter(p,a24)
plt.scatter(p,a25)
plt.scatter(p,a26)
plt.scatter(p,a27)
plt.scatter(p,a28)
plt.scatter(p,a29)
plt.scatter(p,a20)
          
plt.show()

# %% [markdown]
# # Q5

# %%
b11=np.array([[-10],
             [1]])

b12=np.array([[-10],
             [2]])

b13=np.array([[-10],
             [3]])

b14=np.array([[-10],
             [4]])

b15=np.array([[-10],
             [5]])

b16=np.array([[-10],
             [6]])

b17=np.array([[-10],
             [7]])

b18=np.array([[-10],
             [8]])

b19=np.array([[-10],
             [9]])

b01=np.array([[-10],
             [10]])


a11=logsiglayer(w1,p,b11)
a21=linearlayer(w2,a11,b2)

a12=logsiglayer(w1,p,b12)
a22=linearlayer(w2,a12,b2)

a13=logsiglayer(w1,p,b13)
a23=linearlayer(w2,a13,b2)


a14=logsiglayer(w1,p,b14)
a24=linearlayer(w2,a14,b2)

a15=logsiglayer(w1,p,b15)
a25=linearlayer(w2,a15,b2)


a16=logsiglayer(w1,p,b16)
a26=linearlayer(w2,a16,b2)


a17=logsiglayer(w1,p,b17)
a27=linearlayer(w2,a17,b2)


a18=logsiglayer(w1,p,b18)
a28=linearlayer(w2,a18,b2)


a19=logsiglayer(w1,p,b19)
a29=linearlayer(w2,a19,b2)


a10=logsiglayer(w1,p,b01)
a20=linearlayer(w2,a10,b2)





plt.figure(figsize=(10,10))
plt.scatter(p,a21)
plt.scatter(p,a22)
plt.scatter(p,a23)
plt.scatter(p,a24)
plt.scatter(p,a25)
plt.scatter(p,a26)
plt.scatter(p,a27)
plt.scatter(p,a28)
plt.scatter(p,a29)
plt.scatter(p,a20)
          
plt.show()

# %% [markdown]
# # Q6

# %%
w11=np.array([[-1],
             [10]])

w12=np.array([[-0.5],
             [10]])

w13=np.array([[0],
             [10]])

w14=np.array([[0.5],
             [10]])

w15=np.array([[1],
             [10]])



p=np.array([np.linspace(-2,2)])
a11=logsiglayer(w11,p,b1)
a21=linearlayer(w2,a11,b2)


p=np.array([np.linspace(-2,2)])
a12=logsiglayer(w12,p,b1)
a22=linearlayer(w2,a12,b2)


p=np.array([np.linspace(-2,2)])
a13=logsiglayer(w13,p,b1)
a23=linearlayer(w2,a13,b2)


p=np.array([np.linspace(-2,2)])
a14=logsiglayer(w14,p,b1)
a24=linearlayer(w2,a14,b2)


p=np.array([np.linspace(-2,2)])
a15=logsiglayer(w15,p,b1)
a25=linearlayer(w2,a15,b2)


plt.figure(figsize=(10,10))
plt.scatter(p,a21)
plt.scatter(p,a22)
plt.scatter(p,a23)
plt.scatter(p,a24)
plt.scatter(p,a25)


plt.show()

# %% [markdown]
# # Q7

# %%
w21=np.array([[-1,1]])

w22=np.array([[-0.5,1]])

w23=np.array([[0,1]])

w24=np.array([[0.5,1]])

w25=np.array([[1,1]])





p=np.array([np.linspace(-2,2)])
a11=logsiglayer(w1,p,b1)
a21=linearlayer(w21,a11,b2)


p=np.array([np.linspace(-2,2)])
a12=logsiglayer(w1,p,b1)
a22=linearlayer(w22,a12,b2)


p=np.array([np.linspace(-2,2)])
a13=logsiglayer(w1,p,b1)
a23=linearlayer(w23,a13,b2)


p=np.array([np.linspace(-2,2)])
a14=logsiglayer(w1,p,b1)
a24=linearlayer(w24,a14,b2)


p=np.array([np.linspace(-2,2)])
a15=logsiglayer(w1,p,b1)
a25=linearlayer(w25,a15,b2)


plt.figure(figsize=(10,10))
plt.scatter(p,a21)
plt.scatter(p,a22)
plt.scatter(p,a23)
plt.scatter(p,a24)
plt.scatter(p,a25)


plt.show()
